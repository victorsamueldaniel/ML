# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Problem 1
# In this problem we will start looking at a very simple machine learning pipeline.
# We will upload a dataset, perform exploratory data analysis, train some models, and evaluate their performance.
#
# We will work with the California Housing dataset from https://github.com/ageron/handson-ml2/tree/master/datasets/housing.
#
# Our goal is to predict the `median_house_value` by using the other predictors (i.e., columns) of the dataset.

# %%
 # %matplotlib inline
 #coucou

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Load housing dataset

# %% [markdown]
# * Import the `numpy` library as `np`, and `pandas` library as `pd`.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# * Upload the housing dataset `"housing.csv` using the `read_csv()` function from `pandas`. Name the dataframe `housing`.

# %%
housing=pd.read_csv("https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv")

# %% [markdown]
# ### 2. Quick look at the data
# The `housing` dataframe is an object of class `DataFrame`. This class has several methods that allow you to look and modify the data.
# Here, we try to understand the dataset by calling the methods `head()`, `info()`, and `describe()`.

# %% [markdown]
# * What is the difference between the three methods?
#
# *The head() method give the first five rows of the dataset. The info() method give the number of entries as well as the class, number, names of the variables, and the number of non null (no NA) data per variable. While the describe() method give the descriptive statistics of each **quantitative** variable (mean, sd, etc).*
#
# * What are the data types of the columns (i.e., quantitative or qualitative)?
#
# *All the variables are quantitative except the last one: ocean_proximity, which is qualitative.*
#
# * Are there missing values (e.g., NAs)?
#
# *Yes, the variable total_bedroom has 207 NAs.*
#
# * Count the number of rows and column in `housing`.
#
# *There are 10 columns and 20'640 rows.*

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing[housing.isna().any(axis=1)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
#        population  households  median_income  median_house_value  \
# 290         570.0       218.0         4.3750            161900.0
# 341         732.0       259.0         1.6196             85100.0
# 538        3741.0      1273.0         2.5762            173400.0
# 563         384.0       146.0         4.9489            247100.0
# 696         387.0       161.0         3.9063            178400.0
# ...           ...         ...            ...                 ...
# 20267      3171.0       779.0         3.3409            220500.0
# 20268      1938.0       762.0         1.6953            167400.0
# 20372      1701.0       669.0         5.1033            410700.0
# 20460      2734.0       814.0         6.6073            258100.0
# 20484      1705.0       495.0         5.7376            218600.0
#
#       ocean_proximity
# 290          NEAR BAY
# 341          NEAR BAY
# 538          NEAR BAY
# 563          NEAR BAY
# 696          NEAR BAY
# ...               ...
# 20267      NEAR OCEAN
# 20268      NEAR OCEAN
# 20372       <1H OCEAN
# 20460       <1H OCEAN
# 20484       <1H OCEAN
#
# [207 rows x 10 columns]

# %%
housing=housing.dropna()

# %% [markdown]
# ### 3. Exploratory data analysis

# %% [markdown]
# We want to better understand the dataset at hand by performing some exploratory data analysis.

# %% [markdown]
# * Import the `scatter_matrix` function from the `plotting` package of the `pandas` library.

# %%
from pandas.plotting import scatter_matrix

# %% [markdown]
# * Call the `scatter_matrix` function only on the quantitative variables of the `housing` dataset.

# %%
housing_num = housing.select_dtypes(include=[float])
scatter_matrix(housing_num, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6aa15890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a976dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a93e410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a8f3a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a8a9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a86c650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a823cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a7e5250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a7e5290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a79b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a712450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a74aa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a6f8b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a6c5690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a67ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a63f2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a5f58d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a5abed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a56e510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a524b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a4e9150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a49e750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a454d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a418390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a44b990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a404f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a3c85d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a37dbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a341210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a837a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a656390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a4f2c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a312110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a1cd150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a201750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a1b7d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a181b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a0cc310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a0fe2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a0b4950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a06af50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6a02c590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69fe3b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69fa51d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69f5c7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69f12dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69ed5410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69f0ba10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69ec2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69e85650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69e3ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69dfc290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69db5890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69d6be90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69d2d4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69ce5ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69ca8110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69c5d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69c15990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69bcce90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69b903d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69bc68d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69b7cdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69b40310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69af5810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69aaad10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69a6c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69a24750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f699d9c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6999e190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69953690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69988b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f698cc110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f699035d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f698b9ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69863ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69833510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f697e7a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6979ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69761450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f69717950>]],
#       dtype=object)

# %% [markdown]
# * What is the most promising feature to predict `median_house_value`?
#
# `median_income`

# %% [markdown]
# * Are there some features that have a strong skewed distribution? If so, what transformation could help?

# %%
housing_num.skew()
# Out:
# longitude            -0.296141
# latitude              0.464934
# housing_median_age    0.061605
# total_rooms           4.158816
# total_bedrooms        3.459546
# population            4.960017
# households            3.413850
# median_income         1.644557
# median_house_value    0.978290
# dtype: float64

# %% [markdown]
# All except `longitude`, `latitude` and `housing_median_age`
# They are all strongly positively skewed except for `median_income` and `median_house_value`.
# We can apply $log(max_j(x_j)+1-x_i)$, and $sqrt(max_j(x_j)+1-x_i)$ to `median_income` and `median_house_value`

# %% [markdown]
# * Are there some features that are strongly correlated with each other?

# %%
from sklearn.linear_model import LinearRegression
corr_df=pd.DataFrame({col : [0]*9 for col in housing_num.columns},index=[col for col in housing_num.columns])
for col1 in housing_num.columns:
    for col2 in housing_num.drop([col1],axis=1).columns:
        model = LinearRegression()
        model.fit(np.array(housing_num[col1]).reshape((-1, 1)),np.array(housing_num[col2]))
        corr_df.loc[col1,col2]=model.score(np.array(housing_num[col1]).reshape((-1, 1)),np.array(housing_num[col2]))

# %%
corr_df[corr_df>0.75].dropna(how='all').dropna(how='all',axis=1)
# Out:
#                 longitude  latitude  total_rooms  total_bedrooms  population  \
# longitude             NaN  0.854915          NaN             NaN         NaN
# latitude         0.854915       NaN          NaN             NaN         NaN
# total_rooms           NaN       NaN          NaN        0.865606         NaN
# total_bedrooms        NaN       NaN     0.865606             NaN    0.770439
# population            NaN       NaN          NaN        0.770439         NaN
# households            NaN       NaN     0.844545        0.959867    0.822986
#
#                 households
# longitude              NaN
# latitude               NaN
# total_rooms       0.844545
# total_bedrooms    0.959867
# population        0.822986
# households             NaN

# %% [markdown]
# Longitude and latitude strongly correlate with each other
# total_rooms, total_bedrooms, population and household strongly correlate with each other. Except population and total_rooms that have a moderate correlation.

# %% [markdown]
# ### 4. Simple data transformations

# %% [markdown]
# Here, we perform some data transformations, such as data cleaning and feature engineering.

# %% [markdown]
# * Let us start by removing any row containing NAs.

# %%
#already done

# %% [markdown]
# Consider the columns `total_rooms` and `total_bedrooms`, which describe the total number of rooms and bedrooms in a district, and  `population` and `households`, which describe the population and the number of households in a district.
# It is not very useful to know the total number of rooms if we don't know the total number of bedrooms.
# Similarly, the total number of rooms in a district is not very useful if we don't know the number of households.
# Finally, one might be interested in the number of people per household, rather than the total population itself.

# %% [markdown]
# * Based on the observations above, create 3 new features (i.e., columns) that can be more useful than the existing  `total_rooms`, `total_bedrooms`, `population`, and `households`.

# %%
housing['not_bedroom_room']= housing.apply(lambda row: row.total_rooms-row.total_bedrooms, axis=1)
housing['rooms_per_household']=housing.apply(lambda row: row.total_rooms/row.households,axis=1)
housing['people_per_household']=housing.apply(lambda row: row.population/row.households,axis=1)
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  not_bedroom_room  rooms_per_household  \
# 0            NEAR BAY             751.0             6.984127
# 1            NEAR BAY            5993.0             6.238137
# 2            NEAR BAY            1277.0             8.288136
# 3            NEAR BAY            1039.0             5.817352
# 4            NEAR BAY            1347.0             6.281853
# ...               ...               ...                  ...
# 20635          INLAND            1291.0             5.045455
# 20636          INLAND             547.0             6.114035
# 20637          INLAND            1769.0             5.205543
# 20638          INLAND            1451.0             5.329513
# 20639          INLAND            2169.0             5.254717
#
#        people_per_household
# 0                  2.555556
# 1                  2.109842
# 2                  2.802260
# 3                  2.547945
# 4                  2.181467
# ...                     ...
# 20635              2.560606
# 20636              3.122807
# 20637              2.325635
# 20638              2.123209
# 20639              2.616981
#
# [20433 rows x 13 columns]

# %%
housing[housing['people_per_household']>10]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 91       -122.28     37.80                52.0        215.0            87.0
# 270      -122.18     37.78                33.0        142.0            31.0
# 1039     -120.97     38.42                16.0       1748.0           322.0
# 1067     -121.85     39.73                52.0        444.0            80.0
# 1617     -122.08     37.84                17.0       1320.0           159.0
# 2511     -119.54     36.51                36.0         49.0             7.0
# 2723     -115.50     32.75                13.0        330.0            72.0
# 2899     -119.01     35.37                35.0        120.0            35.0
# 3364     -120.51     40.41                36.0         36.0             8.0
# 4479     -118.16     34.07                41.0        247.0            55.0
# 4861     -118.28     34.02                29.0        515.0           229.0
# 5985     -117.71     34.10                41.0        555.0           130.0
# 5986     -117.71     34.10                52.0        567.0           152.0
# 7164     -118.17     34.06                36.0        871.0           201.0
# 8874     -118.45     34.06                52.0        204.0            34.0
# 9172     -118.59     34.47                 5.0        538.0            98.0
# 12104    -117.33     33.97                 8.0        152.0            19.0
# 12443    -115.22     33.54                18.0       1706.0           397.0
# 13034    -121.15     38.69                52.0        240.0            44.0
# 13366    -117.63     33.94                36.0        447.0            95.0
# 14756    -116.97     32.56                23.0       1262.0           294.0
# 14804    -117.17     32.63                26.0       1617.0           279.0
# 15790    -122.40     37.77                52.0        144.0            63.0
# 16171    -122.50     37.79                52.0          8.0             1.0
# 16420    -121.29     37.89                26.0        161.0            27.0
# 16528    -121.17     37.88                22.0       1283.0           256.0
# 16594    -121.29     37.72                22.0       1630.0           404.0
# 16643    -120.65     35.32                20.0        626.0           212.0
# 16669    -120.70     35.32                46.0        118.0            17.0
# 16672    -120.69     35.34                16.0        164.0            30.0
# 17891    -121.93     37.40                34.0        148.0            28.0
# 18520    -122.06     37.00                14.0       1547.0           374.0
# 19006    -121.98     38.32                45.0         19.0             5.0
# 19435    -121.04     37.67                16.0         19.0            19.0
# 19524    -121.00     37.64                19.0        121.0            41.0
# 20121    -120.45     37.79                 8.0       2687.0           495.0
# 20352    -119.09     34.22                 8.0         40.0            10.0
#
#        population  households  median_income  median_house_value  \
# 91          904.0        88.0         0.8668            137500.0
# 270         575.0        47.0         3.8750            225000.0
# 1039       4930.0       287.0         4.3029            121900.0
# 1067       1107.0        98.0         3.4191            137500.0
# 1617       1722.0       141.0        11.7064            500001.0
# 2511         28.0         2.0         4.6250            162500.0
# 2723        822.0        64.0         3.4107            142500.0
# 2899        477.0        41.0         1.9125             47500.0
# 3364       4198.0         7.0         5.5179             67500.0
# 4479        925.0        50.0         3.5769            135700.0
# 4861       2690.0       217.0         0.4999            500001.0
# 5985       1492.0       123.0         2.2813            125000.0
# 5986       2688.0       126.0         1.8750            212500.0
# 7164       2862.0       181.0         2.1845            123800.0
# 8874       1154.0        28.0         9.3370            500001.0
# 9172       8733.0       105.0         4.2391            154600.0
# 12104      1275.0        20.0         1.6250            162500.0
# 12443      3424.0       283.0         1.6250             53500.0
# 13034      6675.0        29.0         6.1359            225000.0
# 13366      2886.0        85.0         4.2578            183300.0
# 14756      5176.0       275.0         2.5625            153300.0
# 14804      2745.0       250.0         3.5357             67500.0
# 15790      1061.0        68.0         4.3958            225000.0
# 16171        13.0         1.0        15.0001            500001.0
# 16420      1542.0        30.0         5.7485            162500.0
# 16528      3082.0       239.0         3.5365            111800.0
# 16594      4402.0       358.0         1.9792             63000.0
# 16643      3574.0       261.0         1.0298            300000.0
# 16669      6532.0        13.0         4.2639            350000.0
# 16672       542.0        32.0         1.6563             42500.0
# 17891       132.0        13.0         3.3750             67500.0
# 18520      4731.0       348.0         2.4732            131300.0
# 19006      7460.0         6.0        10.2264            137500.0
# 19435       166.0         9.0         0.5360            162500.0
# 19524       658.0        41.0         0.9573            162500.0
# 20121      5087.0       385.0         3.1719            115400.0
# 20352       309.0        16.0         4.0208             52500.0
#
#       ocean_proximity  not_bedroom_room  rooms_per_household  \
# 91           NEAR BAY             128.0             2.443182
# 270          NEAR BAY             111.0             3.021277
# 1039           INLAND            1426.0             6.090592
# 1067           INLAND             364.0             4.530612
# 1617         NEAR BAY            1161.0             9.361702
# 2511           INLAND              42.0            24.500000
# 2723           INLAND             258.0             5.156250
# 2899           INLAND              85.0             2.926829
# 3364           INLAND              28.0             5.142857
# 4479        <1H OCEAN             192.0             4.940000
# 4861        <1H OCEAN             286.0             2.373272
# 5985           INLAND             425.0             4.512195
# 5986           INLAND             415.0             4.500000
# 7164        <1H OCEAN             670.0             4.812155
# 8874        <1H OCEAN             170.0             7.285714
# 9172           INLAND             440.0             5.123810
# 12104          INLAND             133.0             7.600000
# 12443          INLAND            1309.0             6.028269
# 13034          INLAND             196.0             8.275862
# 13366          INLAND             352.0             5.258824
# 14756      NEAR OCEAN             968.0             4.589091
# 14804      NEAR OCEAN            1338.0             6.468000
# 15790        NEAR BAY              81.0             2.117647
# 16171        NEAR BAY               7.0             8.000000
# 16420          INLAND             134.0             5.366667
# 16528          INLAND            1027.0             5.368201
# 16594          INLAND            1226.0             4.553073
# 16643      NEAR OCEAN             414.0             2.398467
# 16669      NEAR OCEAN             101.0             9.076923
# 16672      NEAR OCEAN             134.0             5.125000
# 17891       <1H OCEAN             120.0            11.384615
# 18520      NEAR OCEAN            1173.0             4.445402
# 19006          INLAND              14.0             3.166667
# 19435          INLAND               0.0             2.111111
# 19524          INLAND              80.0             2.951220
# 20121          INLAND            2192.0             6.979221
# 20352      NEAR OCEAN              30.0             2.500000
#
#        people_per_household
# 91                10.272727
# 270               12.234043
# 1039              17.177700
# 1067              11.295918
# 1617              12.212766
# 2511              14.000000
# 2723              12.843750
# 2899              11.634146
# 3364             599.714286
# 4479              18.500000
# 4861              12.396313
# 5985              12.130081
# 5986              21.333333
# 7164              15.812155
# 8874              41.214286
# 9172              83.171429
# 12104             63.750000
# 12443             12.098940
# 13034            230.172414
# 13366             33.952941
# 14756             18.821818
# 14804             10.980000
# 15790             15.602941
# 16171             13.000000
# 16420             51.400000
# 16528             12.895397
# 16594             12.296089
# 16643             13.693487
# 16669            502.461538
# 16672             16.937500
# 17891             10.153846
# 18520             13.594828
# 19006           1243.333333
# 19435             18.444444
# 19524             16.048780
# 20121             13.212987
# 20352             19.312500

# %% [markdown]
# * At this point, look at the scatter matrix of the 3 newly created columns. Is the skewness of some of the new variables better compared to  `total_rooms`, `total_bedrooms`, `population`, and `households`?
#
# *Yes, the skewness is much better !*

# %%
scatter_matrix(
    housing[
        (housing['people_per_household']<10) & (housing['rooms_per_household']<30)
            ].iloc[:,-3:],
    figsize=(10,10)
    )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f670928d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55ac6a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55aefb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55c97690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55ce9c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55c782d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55bed950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55b68e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f55b68ed0>]],
#       dtype=object)

# %% [markdown]
# * Compute the correlation among the  3 new variables. Also, compute the correlation between  `total_rooms`, `total_bedrooms`, `population`, and `households`. What do you observe?
#
# *The new variables don't correlate anymore with each other*

# %%
housing[(housing['people_per_household']<10) & (housing['rooms_per_household']<30)].iloc[:,-3:].skew()
# Out:
# not_bedroom_room        4.315245
# rooms_per_household     4.447209
# people_per_household    1.394554
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
housing_new=housing.iloc[:,-3:]
corr_housing_new=pd.DataFrame({col : [0]*3 for col in housing_new.columns},index=[col for col in housing_new.columns])
for col1 in housing_new.columns:
    for col2 in housing_new.drop([col1],axis=1).columns:
        model = LinearRegression()
        model.fit(np.array(housing_new[col1]).reshape((-1, 1)),np.array(housing_new[col2]))
        corr_housing_new.loc[col1,col2]=model.score(np.array(housing_new[col1]).reshape((-1, 1)),np.array(housing_new[col2]))

# %%
print(corr_df.loc[['total_rooms','total_bedrooms','households']][['total_rooms','total_bedrooms','households']])
print(corr_housing_new)
# Out:
#                 total_rooms  total_bedrooms  households
# total_rooms        0.000000        0.865606    0.844545
# total_bedrooms     0.865606        0.000000    0.959867
# households         0.844545        0.959867    0.000000
#                       rooms_per_household  ...  ocean_proximity_enc
# rooms_per_household              0.000000  ...             0.000007
# people_per_household             0.000024  ...             0.000084
# ocean_proximity_enc              0.000007  ...             0.000000
#
# [3 rows x 3 columns]

# %% [markdown]
# The column `ocean_proximity` is a qualitative variable with different categories. It is always good to convert qualitative variables into quantitative before fitting machine learning models. To do so, we will use the `OrdinalEncoder` function from the `preprocessing` package of the `sklearn` library.

# %% [markdown]
# * Import the `OrdinalEncoder` function.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# We first instantiate an object from class `OrdinalEncoder` and we call it `my_ordinal_encoder`.

# %%
my_ordinal_encoder=OrdinalEncoder()

# %% [markdown]
# Create a new column named `ocean_proximity_enc` by transforming the `ocean_proximity` column with the `my_ordinal_encoder.fit_transform` function.
#
# _Hint_: Make sure you access the `ocean_proximity` column with the double bracket `[[` and not with the single bracket `[`.

# %%
housing['ocean_proximity_enc']=my_ordinal_encoder.fit_transform(housing[['ocean_proximity']])

# %% [markdown]
# ### 5. Split data into train and test

# %% [markdown]
# If we fit and evaluate our model on the same data we obtain overly optimistic results. For this reason, we have to split the dataset into a train and test part.

# %% [markdown]
# * Split the data by keeping 20% of the observations in the test set. Set the random seed to `42`. Fill the `??` below.

# %%
from sklearn.model_selection import train_test_split

# %%
housing_train, housing_test = train_test_split(housing, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### 6. Fit simple models

# %% [markdown]
# We are now almost ready to fit our first two models, KNN and LinearRegression. Before doing so, let us split the data into predictors and response.

# %% [markdown]
# * Split the `housing` dataset into predictors `X` and response `y`. From `X`, remove the columns `total_rooms`, `total_bedrooms`, `population`, `households`, and `ocean_proximity`.

# %%
x=housing_train.drop(['median_house_value','total_rooms','total_bedrooms','population','households','ocean_proximity'],axis=1)
y=housing_train['median_house_value']

# %% [markdown]
# * Let us first fit a KNN model (fill the `??`).

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(x, y)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %% [markdown]
# * Let us now fit a Linear Regression model (fill the `??`)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### 7. Make predictions and evaluate models

# %% [markdown]
# We now want to make some predictions on test set, i.e., `X_test`, and to evaluate how well the models perform.

# %% [markdown]
# * Create the `X_test` and `y_test`.

# %%
x_test=housing_test.drop(['median_house_value','total_rooms','total_bedrooms','population','households','ocean_proximity'],axis=1)
y_test=housing_test['median_house_value']

# %% [markdown]
# * Predict the fitted models on the test set `X_test`.
#
# _Hint_: use the `<fitted_object>.predict` function.

# %%
knn_pred=knn.predict(x_test)
linreg_pred=lin_reg.predict(x_test)

# %% [markdown]
# * Evaluate the performance of the models using the root mean square error (RMSE). Fill the `??`.

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(knn_pred, y_test))
# Out:
# 108183.5877361718

# %%
np.sqrt(mean_squared_error(linreg_pred, y_test))
# Out:
# 74221.00560996674

# %% [markdown]
# ## Problem 2
# In this problem, we show that the regression function $f^*(x) := \operatorname{E}[Y \mid X = x]$, $x \in \mathbb{R}^p$, is **optimal** in the sense that it minimizes the expected squared prediction error.
#
# In particular, for a fixed predictor value $x \in \mathbb{R}^p$, we want to show that
#
# $$f^*(x) =
# \underset{f(x)}{\operatorname{arg min}} \operatorname{E}\left[\left(Y - f(x)\right)^2 \mid X = x\right].$$

# %% [markdown]
# \begin{align*}
# &&\frac{\partial}{\partial f(x)}\operatorname{E}\left[\left(Y - f(x)\right)^2 \mid X = x\right] &=0\\
# \Leftrightarrow &&\operatorname{E}\left[\frac{\partial}{\partial f(x)}\left(\left(Y - f(x)\right)^2\right) \mid X = x\right] &=0&\text{by linearity of }\operatorname{E}\\
# \Leftrightarrow &&\operatorname{E}\left[-2\cdot\left(Y - f(x)\right) \mid X = x\right]&=0\\
# \Leftrightarrow &&-2\operatorname{E}\left[Y - f(x) \mid X = x\right]&=0&\text{by linearity of }\operatorname{E}\\
# \Leftrightarrow &&\operatorname{E}\left[Y - f(x) \mid X = x\right]&=0&\\
# \Leftrightarrow &&\operatorname{E}\left[Y \mid X=x\right]&=\operatorname{E}\left[f(x) \mid X=x\right]&\text{by linearity of }\operatorname{E}\\
# \Leftrightarrow &&\operatorname{E}\left[Y \mid X=x\right]&=f(x)&\text{RHS is deterministic}
# \end{align*}
#
# Moreover,
# \begin{equation}
# \frac{\partial^2}{\partial f(x)^2}\operatorname{E}\left[\left(Y - f(x)\right)^2 \mid X =x\right]=\operatorname{E}\left[\frac{\partial}{\partial f(x)}\left(-2\cdot\left(Y - f(x)\right)\right) \mid X = x\right]=E\left[2 \mid X=x\right]=2>0,
# \end{equation}
# meaning the function to minimise is convex.
#
# Therefore the function minimizing MSE is $f^*(x):= \operatorname{E}[Y \mid X = x]$
